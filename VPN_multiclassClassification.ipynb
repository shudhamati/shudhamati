# %%
from scipy.io import arff
df=arff.loadarff("C:\\Users\\Shuddhamati\\Desktop\\datasets\\Scenario B\\Scenario B\\TimeBasedFeatures-Dataset-30s-AllinOne.arff")

# %%
import pandas as pd 
df=pd.DataFrame(df[0])

# %%
df.head()
# Out:
#      duration  total_fiat  total_biat    min_fiat    min_biat       max_fiat  \
# 0  22930417.0        18.0         4.0  10995965.0  10960941.0  314115.301370
# 1  25199304.0        16.0         4.0  11037969.0  10851858.0  359269.900000
# 2  29772995.0        17.0         7.0   4093396.0   3956161.0  261815.256637
# 3  29609149.0        22.0         6.0   3954677.0   3943698.0  271180.963303
# 4   7863522.0        30.0         8.0   2067690.0   2068091.0  244213.125000
#
#         max_biat     mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0  360993.158730  1.306745e+06  1.389355e+06           6.018207  ...
# 1  387414.676923  1.373362e+06  1.392885e+06           5.436658  ...
# 2  310135.364583  6.445422e+05  6.512717e+05           7.086959  ...
# 3  287136.446602  6.685474e+05  6.590460e+05           7.227496  ...
# 4  252051.483871  5.718062e+05  5.628123e+05           8.266016  ...
#
#      std_flowiat  min_active   mean_active  max_active    std_active  \
# 0  952994.511204   1491627.0  5.011278e+06  11141326.0  4.507600e+06
# 1  976395.388090   1710925.0  4.164396e+06  14269600.0  4.973926e+06
# 2  462297.947930   1363299.0  2.706523e+06   6192566.0  1.445372e+06
# 3  472527.270988   1443143.0  2.937555e+06   4176130.0  8.769669e+05
# 4  400581.170736   2092947.0  2.535199e+06   3282729.0  6.509928e+05
#
#     min_idle     mean_idle    max_idle      std_idle   class1
# 0  1079974.0  3.668800e+06  10945954.0  4.855368e+06  b'CHAT'
# 1  1234883.0  3.150269e+06  10851858.0  3.797336e+06  b'CHAT'
# 2  1147658.0  1.955468e+06   3956161.0  8.938483e+05  b'CHAT'
# 3  1065834.0  2.022585e+06   3895269.0  9.303813e+05  b'CHAT'
# 4  1707343.0  1.897912e+06   2017289.0  1.667869e+05  b'CHAT'
#
# [5 rows x 24 columns]

# %%
df['class1']. nunique()
# Out:
# 7

# %%
df.drop(df[(df['total_fiat'])==-1].index,inplace=True)
df.drop(df[(df['total_biat'])==-1].index,inplace=True)

# %%
import seaborn as sns
sns.barplot(y='total_fiat',x='class1',data=df)
# Out:
# <AxesSubplot:xlabel='class1', ylabel='total_fiat'>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dfle=df
df.class1=le.fit_transform(df.class1)

# %%
dfle
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# 1      3.592699e+05  3.874147e+05  1.373362e+06  1.392885e+06
# 2      2.618153e+05  3.101354e+05  6.445422e+05  6.512717e+05
# 3      2.711810e+05  2.871364e+05  6.685474e+05  6.590460e+05
# 4      2.442131e+05  2.520515e+05  5.718062e+05  5.628123e+05
# ...             ...           ...           ...           ...
# 14605  7.004646e+06  7.018758e+06  3.039852e+03  3.351615e+04
# 14608  7.007075e+06  6.994682e+06  1.233194e+04  4.688118e+03
# 14621  5.017300e+04  3.359633e+04  7.074886e+04  5.809529e+04
# 14622  5.091800e+04  3.380300e+04  7.179397e+04  5.845845e+04
# 14623  5.030550e+04  3.375967e+04  7.091220e+04  5.838945e+04
#
#        flowPktsPerSecond  ...   std_flowiat  min_active   mean_active  \
# 0               6.018207  ...  9.529945e+05   1491627.0  5.011278e+06
# 1               5.436658  ...  9.763954e+05   1710925.0  4.164396e+06
# 2               7.086959  ...  4.622979e+05   1363299.0  2.706523e+06
# 3               7.227496  ...  4.725273e+05   1443143.0  2.937555e+06
# 4               8.266016  ...  4.005812e+05   2092947.0  2.535199e+06
# ...                  ...  ...           ...         ...           ...
# 14605           0.420936  ...  3.599758e+06   7002496.0  7.004646e+06
# 14608           0.422320  ...  3.614942e+06   6998355.0  7.007075e+06
# 14621          34.850838  ...  5.171026e+04        -1.0  0.000000e+00
# 14622          34.483438  ...  5.227691e+04        -1.0  0.000000e+00
# 14623          34.718434  ...  5.191754e+04        -1.0  0.000000e+00
#
#        max_active    std_active   min_idle     mean_idle    max_idle  \
# 0      11141326.0  4.507600e+06  1079974.0  3.668800e+06  10945954.0
# 1      14269600.0  4.973926e+06  1234883.0  3.150269e+06  10851858.0
# 2       6192566.0  1.445372e+06  1147658.0  1.955468e+06   3956161.0
# 3       4176130.0  8.769669e+05  1065834.0  2.022585e+06   3895269.0
# 4       3282729.0  6.509928e+05  1707343.0  1.897912e+06   2017289.0
# ...           ...           ...        ...           ...         ...
# 14605   7006795.0  3.039852e+03  6790373.0  6.794092e+06   6797810.0
# 14608   7015795.0  1.233194e+04  6797910.0  6.801404e+06   6804898.0
# 14621        -1.0  0.000000e+00       -1.0  0.000000e+00        -1.0
# 14622        -1.0  0.000000e+00       -1.0  0.000000e+00        -1.0
# 14623        -1.0  0.000000e+00       -1.0  0.000000e+00        -1.0
#
#            std_idle  class1
# 0      4.855368e+06       1
# 1      3.797336e+06       1
# 2      8.938483e+05       1
# 3      9.303813e+05       1
# 4      1.667869e+05       1
# ...             ...     ...
# 14605  5.258753e+03       4
# 14608  4.941262e+03       4
# 14621  0.000000e+00       4
# 14622  0.000000e+00       4
# 14623  0.000000e+00       4
#
# [11312 rows x 24 columns]

# %%
target=df.class1

# %%
features=df.drop(['class1'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features,target, test_size=0.1, random_state=5)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.9346289752650176

# %%
from sklearn.tree import DecisionTreeClassifier
treemodel=DecisionTreeClassifier()
treemodel.fit(X_train,y_train)
treemodel.score(X_test,y_test)
# Out:
# 0.8825088339222615

# %%
df.corr()
# Out:
#                     duration  total_fiat  total_biat  min_fiat  min_biat  \
# duration            1.000000   -0.004693   -0.001920  0.591854  0.531474
# total_fiat         -0.004693    1.000000    0.839752  0.153312  0.177357
# total_biat         -0.001920    0.839752    1.000000  0.153657  0.193490
# min_fiat            0.591854    0.153312    0.153657  1.000000  0.167692
# min_biat            0.531474    0.177357    0.193490  0.167692  1.000000
# max_fiat            0.298030    0.752180    0.679479  0.614633  0.200497
# max_biat            0.112926    0.778217    0.896394  0.213167  0.433529
# mean_fiat           0.544180   -0.081563   -0.022128  0.892790  0.091433
# mean_biat           0.391242   -0.037430   -0.091396  0.147547  0.784807
# flowPktsPerSecond  -0.096627   -0.042031   -0.042778 -0.062596 -0.059646
# flowBytesPerSecond -0.073218   -0.030223   -0.030825 -0.044073 -0.041950
# min_flowiat        -0.014535    0.550043    0.571009  0.084226  0.107315
# max_flowiat         0.806577    0.097113    0.105453  0.768298  0.680106
# mean_flowiat        0.437088    0.583292    0.613689  0.655130  0.347351
# std_flowiat         0.644601    0.335002    0.352715  0.801033  0.473007
# min_active          0.739071    0.121783    0.122814  0.703437  0.604939
# mean_active         0.787156    0.108851    0.113539  0.745564  0.649773
# max_active          0.812296    0.090320    0.097185  0.763932  0.676795
# std_active          0.286665   -0.054426   -0.034197  0.262492  0.272261
# min_idle            0.735946    0.127158    0.128476  0.704525  0.605508
# mean_idle           0.781703    0.115622    0.121124  0.747615  0.651178
# max_idle            0.805849    0.098173    0.106529  0.768992  0.680870
# std_idle            0.281539   -0.049083   -0.026353  0.273619  0.282676
# class1              0.126514    0.157970    0.146810 -0.225688 -0.192603
#
#                     max_fiat  max_biat  mean_fiat  mean_biat  \
# duration            0.298030  0.112926   0.544180   0.391242
# total_fiat          0.752180  0.778217  -0.081563  -0.037430
# total_biat          0.679479  0.896394  -0.022128  -0.091396
# min_fiat            0.614633  0.213167   0.892790   0.147547
# min_biat            0.200497  0.433529   0.091433   0.784807
# max_fiat            1.000000  0.708558   0.560016   0.096686
# max_biat            0.708558  1.000000   0.077133   0.322111
# mean_fiat           0.560016  0.077133   1.000000   0.179367
# mean_biat           0.096686  0.322111   0.179367   1.000000
# flowPktsPerSecond  -0.057326 -0.061754  -0.040886  -0.049298
# flowBytesPerSecond -0.041466 -0.044834  -0.029667  -0.035984
# min_flowiat         0.431261  0.521534  -0.030252  -0.041296
# max_flowiat         0.459182  0.267291   0.693573   0.536552
# mean_flowiat        0.917439  0.720957   0.649151   0.303606
# std_flowiat         0.762201  0.513841   0.794483   0.464012
# min_active          0.460264  0.254094   0.654882   0.464358
# mean_active         0.463620  0.261552   0.682433   0.505532
# max_active          0.448768  0.257557   0.685646   0.531278
# std_active          0.047882  0.062706   0.182285   0.248712
# min_idle            0.467364  0.260312   0.658887   0.466391
# mean_idle           0.472547  0.270133   0.687653   0.508879
# max_idle            0.460056  0.268742   0.693591   0.537271
# std_idle            0.057763  0.074628   0.192463   0.260339
# class1              0.008819  0.034169  -0.216770  -0.259083
#
#                     flowPktsPerSecond  ...  std_flowiat  min_active  \
# duration                    -0.096627  ...     0.644601    0.739071
# total_fiat                  -0.042031  ...     0.335002    0.121783
# total_biat                  -0.042778  ...     0.352715    0.122814
# min_fiat                    -0.062596  ...     0.801033    0.703437
# min_biat                    -0.059646  ...     0.473007    0.604939
# max_fiat                    -0.057326  ...     0.762201    0.460264
# max_biat                    -0.061754  ...     0.513841    0.254094
# mean_fiat                   -0.040886  ...     0.794483    0.654882
# mean_biat                   -0.049298  ...     0.464012    0.464358
# flowPktsPerSecond            1.000000  ...    -0.058799   -0.043266
# flowBytesPerSecond           0.847355  ...    -0.042260   -0.030118
# min_flowiat                 -0.029305  ...     0.206772    0.063354
# max_flowiat                 -0.056369  ...     0.856601    0.929921
# mean_flowiat                -0.061612  ...     0.909850    0.606218
# std_flowiat                 -0.058799  ...     1.000000    0.818901
# min_active                  -0.043266  ...     0.818901    1.000000
# mean_active                 -0.050948  ...     0.847066    0.983101
# max_active                  -0.058445  ...     0.843826    0.929474
# std_active                  -0.039245  ...     0.201639   -0.040172
# min_idle                    -0.042016  ...     0.825975    0.995987
# mean_idle                   -0.049118  ...     0.856351    0.980363
# max_idle                    -0.056201  ...     0.856816    0.929665
# std_idle                    -0.037573  ...     0.216329   -0.035275
# class1                      -0.014697  ...    -0.153640   -0.156476
#
#                     mean_active  max_active  std_active  min_idle  mean_idle  \
# duration               0.787156    0.812296    0.286665  0.735946   0.781703
# total_fiat             0.108851    0.090320   -0.054426  0.127158   0.115622
# total_biat             0.113539    0.097185   -0.034197  0.128476   0.121124
# min_fiat               0.745564    0.763932    0.262492  0.704525   0.747615
# min_biat               0.649773    0.676795    0.272261  0.605508   0.651178
# max_fiat               0.463620    0.448768    0.047882  0.467364   0.472547
# max_biat               0.261552    0.257557    0.062706  0.260312   0.270133
# mean_fiat              0.682433    0.685646    0.182285  0.658887   0.687653
# mean_biat              0.505532    0.531278    0.248712  0.466391   0.508879
# flowPktsPerSecond     -0.050948   -0.058445   -0.039245 -0.042016  -0.049118
# flowBytesPerSecond    -0.035596   -0.040962   -0.027932 -0.029130  -0.034222
# min_flowiat            0.058536    0.048988   -0.015194  0.066202   0.062707
# max_flowiat            0.977285    0.992306    0.306720  0.932813   0.981401
# mean_flowiat           0.619530    0.608352    0.111403  0.614149   0.629927
# std_flowiat            0.847066    0.843826    0.201639  0.825975   0.856351
# min_active             0.983101    0.929474   -0.040172  0.995987   0.980363
# mean_active            1.000000    0.980315    0.141719  0.978519   0.995232
# max_active             0.980315    1.000000    0.325393  0.924458   0.973340
# std_active             0.141719    0.325393    1.000000 -0.043350   0.131105
# min_idle               0.978519    0.924458   -0.043350  1.000000   0.983783
# mean_idle              0.995232    0.973340    0.131105  0.983783   1.000000
# max_idle               0.977260    0.992580    0.307748  0.932435   0.981217
# std_idle               0.142692    0.320361    0.977990 -0.038013   0.140362
# class1                -0.193432   -0.231173   -0.184724 -0.151821  -0.186340
#
#                     max_idle  std_idle    class1
# duration            0.805849  0.281539  0.126514
# total_fiat          0.098173 -0.049083  0.157970
# total_biat          0.106529 -0.026353  0.146810
# min_fiat            0.768992  0.273619 -0.225688
# min_biat            0.680870  0.282676 -0.192603
# max_fiat            0.460056  0.057763  0.008819
# max_biat            0.268742  0.074628  0.034169
# mean_fiat           0.693591  0.192463 -0.216770
# mean_biat           0.537271  0.260339 -0.259083
# flowPktsPerSecond  -0.056201 -0.037573 -0.014697
# flowBytesPerSecond -0.039352 -0.026929 -0.010030
# min_flowiat         0.054528 -0.009484  0.115038
# max_flowiat         0.999921  0.319628 -0.220446
# mean_flowiat        0.622020  0.124919 -0.030182
# std_flowiat         0.856816  0.216329 -0.153640
# min_active          0.929665 -0.035275 -0.156476
# mean_active         0.977260  0.142692 -0.193432
# max_active          0.992580  0.320361 -0.231173
# std_active          0.307748  0.977990 -0.184724
# min_idle            0.932435 -0.038013 -0.151821
# mean_idle           0.981217  0.140362 -0.186340
# max_idle            1.000000  0.320500 -0.222925
# std_idle            0.320500  1.000000 -0.179964
# class1             -0.222925 -0.179964  1.000000
#
# [24 rows x 24 columns]

# %%
df.drop('mean_flowiat',axis=1,inplace=True)
df.drop('mean_active',axis=1,inplace=True)
df.drop('min_active',axis=1,inplace=True)

# %%
df.drop('max_active',axis=1,inplace=True)

# %%
df.drop('max_idle',axis=1,inplace=True)
df.drop('mean_idle',axis=1,inplace=True)

# %%
df.drop('std_active',axis=1,inplace=True)

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#      duration  total_fiat  total_biat    min_fiat    min_biat       max_fiat  \
# 0  22930417.0        18.0         4.0  10995965.0  10960941.0  314115.301370
# 1  25199304.0        16.0         4.0  11037969.0  10851858.0  359269.900000
# 2  29772995.0        17.0         7.0   4093396.0   3956161.0  261815.256637
# 3  29609149.0        22.0         6.0   3954677.0   3943698.0  271180.963303
# 4   7863522.0        30.0         8.0   2067690.0   2068091.0  244213.125000
#
#         max_biat     mean_fiat     mean_biat  flowPktsPerSecond  \
# 0  360993.158730  1.306745e+06  1.389355e+06           6.018207
# 1  387414.676923  1.373362e+06  1.392885e+06           5.436658
# 2  310135.364583  6.445422e+05  6.512717e+05           7.086959
# 3  287136.446602  6.685474e+05  6.590460e+05           7.227496
# 4  252051.483871  5.718062e+05  5.628123e+05           8.266016
#
#    flowBytesPerSecond  min_flowiat  max_flowiat    std_flowiat   min_idle  \
# 0         2232.187928          4.0   10945954.0  952994.511204  1079974.0
# 1         2559.792921          4.0   10851858.0  976395.388090  1234883.0
# 2         2544.453455          7.0    3956161.0  462297.947930  1147658.0
# 3         3199.011225          6.0    3895269.0  472527.270988  1065834.0
# 4         3567.866918          8.0    2017289.0  400581.170736  1707343.0
#
#        std_idle  class1
# 0  4.855368e+06       1
# 1  3.797336e+06       1
# 2  8.938483e+05       1
# 3  9.303813e+05       1
# 4  1.667869e+05       1

# %%
df.shape
# Out:
# (11312, 17)

# %%
features1=df.drop(['class1'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features1,target, test_size=0.1, random_state=5)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
treemodel=DecisionTreeClassifier()

# %%
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
treemodel.score(X_test,y_test)
# Out:
# 0.8719081272084805

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.9302120141342756

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
treemodel=DecisionTreeClassifier()

# %%
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
treemodel.score(X_test,y_test)
# Out:
# 0.8851590106007067

# %%
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression()

# %%
model1.fit(X_train,y_train)
# Out:
# C:\Users\Shuddhamati\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model1.score(X_test,y_test)
# Out:
# 0.6581272084805654

# %%
from sklearn.svm import SVC
svm = SVC()

# %%
svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
svm.score(X_test,y_test)
# Out:
# 0.6598939929328622
